# %% [markdown]
# **Use GPU: Runtime -> Change runtime type -> GPU (Hardware Accelerator)**

# %% [markdown]
# Setup

# %%
# !cat ~/.keras/keras.json
# Out:
# {
#     "epsilon": 1e-07,
#     "floatx": "float32",
#     "image_data_format": "channels_last",
#     "backend": "tensorflow"
# }

# %%
import keras
print(keras.__version__)
# Out:
# 2.4.3

# %% [markdown]
# DCGAN

# %%
# import the necessary packages
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2DTranspose
from keras.layers.convolutional import Conv2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers.core import Reshape

class DCGAN:
	@staticmethod
	def build_generator(dim, depth, channels=1, inputDim=100, outputDim=512):
		# initialize the model along with the input shape to be
		# "channels last" and the channels dimension itself
		model = Sequential()
		inputShape = (dim, dim, depth)
		chanDim = -1

		# first set of FC => RELU => BN layers
		model.add(Dense(input_dim=inputDim, units=outputDim))
		model.add(Activation("relu"))
		model.add(BatchNormalization())

		# second set of FC => RELU => BN layers, this time preparing
		# the number of FC nodes to be reshaped into a volume
		model.add(Dense(dim * dim * depth))
		model.add(Activation("relu"))
		model.add(BatchNormalization())

		# reshape the output of the previous layer set, upsample +
		# apply a transposed convolution, RELU, and BN
		model.add(Reshape(inputShape))
		model.add(Conv2DTranspose(32, (5, 5), strides=(2, 2), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))

		# apply another upsample and transposed convolution, but
		# this time output the TANH activation
		model.add(Conv2DTranspose(channels, (5, 5), strides=(2, 2), padding="same"))
		model.add(Activation("tanh"))

		# return the generator model
		return model

	@staticmethod
	def build_discriminator(width, height, depth, alpha=0.2):
		# initialize the model along with the input shape to be
		# "channels last"
		model = Sequential()
		inputShape = (height, width, depth)

		# first set of CONV => RELU layers
		model.add(Conv2D(32, (5, 5), padding="same", strides=(2, 2), input_shape=inputShape))
		model.add(LeakyReLU(alpha=alpha))

		# second set of CONV => RELU layers
		model.add(Conv2D(64, (5, 5), padding="same", strides=(2, 2)))
		model.add(LeakyReLU(alpha=alpha))

		# first (and only) set of FC => RELU layers
		model.add(Flatten())
		model.add(Dense(512))
		model.add(LeakyReLU(alpha=alpha))

		# sigmoid layer outputting a single value
		model.add(Dense(1))
		model.add(Activation("sigmoid"))

		# return the discriminator model
		return model

# %% [markdown]
# Train DCGAN w/ MNIST

# %%
from keras.models import Model
from keras.layers import Input
from keras.optimizers import Adam
from keras.datasets import mnist
from sklearn.utils import shuffle
from imutils import build_montages
import numpy as np
import cv2
import os

# %%
def train_dcgan_mnist(output_folderpath, epochs=50, batch_size=128):
    # store the epochs and batch size in convenience variables
    NUM_EPOCHS = epochs
    BATCH_SIZE = batch_size

    # load the MNIST dataset and stack the training and testing data
    # points so we have additional training data
    print("[INFO] loading MNIST dataset...")
    ((trainX, _), (testX, _)) = mnist.load_data()
    trainImages = np.concatenate([trainX, testX])

    # add in an extra dimension for the channel and scale the images
    # into the range [-1, 1] (which is the range of the tanh
    # function)
    trainImages = np.expand_dims(trainImages, axis=-1)
    trainImages = (trainImages.astype("float") - 127.5) / 127.5

    # build the generator
    print("[INFO] building generator...")
    gen = DCGAN.build_generator(7, 64, channels=1)

    # build the discriminator
    print("[INFO] building discriminator...")
    disc = DCGAN.build_discriminator(28, 28, 1)
    discOpt = Adam(lr=0.0002, beta_1=0.5, decay=0.0002 / NUM_EPOCHS)
    disc.compile(loss="binary_crossentropy", optimizer=discOpt)

    # build the adversarial model by first setting the discriminator to
    # *not* be trainable, then combine the generator and discriminator
    # together
    print("[INFO] building GAN...")
    disc.trainable = False
    ganInput = Input(shape=(100,))
    ganOutput = disc(gen(ganInput))
    gan = Model(ganInput, ganOutput)

    # compile the GAN
    ganOpt = Adam(lr=0.0002, beta_1=0.5, decay=0.0002 / NUM_EPOCHS)
    gan.compile(loss="binary_crossentropy", optimizer=discOpt)

    # randomly generate some benchmark noise so we can consistently
    # visualize how the generative modeling is learning
    print("[INFO] starting training...")
    benchmarkNoise = np.random.uniform(-1, 1, size=(256, 100))

    # loop over the epochs
    for epoch in range(NUM_EPOCHS):
        # show epoch information and compute the number of batches per
        # epoch
        print("[INFO] starting epoch {} of {}...".format(epoch + 1, NUM_EPOCHS))
        batchesPerEpoch = int(trainImages.shape[0] / BATCH_SIZE)

        # loop over the batches
        for i in range(0, batchesPerEpoch):
            # initialize an (empty) output path
            p = None

            # select the next batch of images, then randomly generate
            # noise for the generator to predict on
            imageBatch = trainImages[i * BATCH_SIZE:(i + 1) * BATCH_SIZE]
            noise = np.random.uniform(-1, 1, size=(BATCH_SIZE, 100))

            # generate images using the noise + generator model
            genImages = gen.predict(noise, verbose=0)

            # concatenate the *actual* images and the *generated* images,
            # construct class labels for the discriminator, and shuffle
            # the data
            X = np.concatenate((imageBatch, genImages))
            y = ([1] * BATCH_SIZE) + ([0] * BATCH_SIZE)
            (X, y) = shuffle(X, y)

            # convert to numpy array as input for train_on_batch
            X = np.array(X)
            y = np.array(y)

            # train the discriminator on the data
            discLoss = disc.train_on_batch(X, y)

            # let's now train our generator via the adversarial model by
            # (1) generating random noise and (2) training the generator
            # with the discriminator weights frozen
            noise = np.random.uniform(-1, 1, (BATCH_SIZE, 100))
            ganLoss = gan.train_on_batch(noise, np.array([1] * BATCH_SIZE))

            # check to see if this is the end of an epoch, and if so,
            # initialize the output path
            if i == batchesPerEpoch - 1:
                p = [output_folderpath, "epoch_{}_output.png".format(str(epoch + 1).zfill(4))]

            # otherwise, check to see if we should visualize the current
            # batch for the epoch
            else:
                # create more visualizations early in the training
                # process
                if epoch < 10 and i % 25 == 0:
                    p = [output_folderpath, "epoch_{}_step_{}.png".format(str(epoch + 1).zfill(4), str(i).zfill(5))]

                # visualizations later in the training process are less
                # interesting
                elif epoch >= 10 and i % 100 == 0:
                    p = [output_folderpath, "epoch_{}_step_{}.png".format(str(epoch + 1).zfill(4), str(i).zfill(5))]

            # check to see if we should visualize the output of the
            # generator model on our benchmark data
            if p is not None:
                # show loss information
                print("[INFO] Step {}_{}: discriminator_loss={:.6f}, adversarial_loss={:.6f}".format(epoch + 1, i, discLoss, ganLoss))

                # make predictions on the benchmark noise, scale it back
                # to the range [0, 255], and generate the montage
                images = gen.predict(benchmarkNoise)
                images = ((images * 127.5) + 127.5).astype("uint8")
                images = np.repeat(images, 3, axis=-1)
                vis = build_montages(images, (28, 28), (16, 16))[0]

                # write the visualization to disk
                p = os.path.sep.join(p)
                cv2.imwrite(p, vis)

    print("[INFO] done.")

# %%
train_dcgan_mnist(output_folderpath="drive/MyDrive/pyimagesearch/output/34-dcgan-mnist")
# Out:
# [INFO] loading MNIST dataset...
# [INFO] building generator...
# [INFO] building discriminator...
# [INFO] building GAN...
# [INFO] starting training...
# [INFO] starting epoch 1 of 50...
# [INFO] Step 1_0: discriminator_loss=0.723051, adversarial_loss=0.668614
# [INFO] Step 1_25: discriminator_loss=0.029240, adversarial_loss=2.033889
# [INFO] Step 1_50: discriminator_loss=0.001854, adversarial_loss=0.918732
# [INFO] Step 1_75: discriminator_loss=2.205439, adversarial_loss=0.000179
# [INFO] Step 1_100: discriminator_loss=0.042607, adversarial_loss=0.413303
# [INFO] Step 1_125: discriminator_loss=0.026780, adversarial_loss=0.593967
# [INFO] Step 1_150: discriminator_loss=0.033350, adversarial_loss=1.414719
# [INFO] Step 1_175: discriminator_loss=0.035503, adversarial_loss=3.116061
# [INFO] Step 1_200: discriminator_loss=0.456335, adversarial_loss=4.507927
# [INFO] Step 1_225: discriminator_loss=0.388223, adversarial_loss=3.880646
# [INFO] Step 1_250: discriminator_loss=0.377872, adversarial_loss=2.381344
# [INFO] Step 1_275: discriminator_loss=0.612590, adversarial_loss=0.377042
# [INFO] Step 1_300: discriminator_loss=0.326392, adversarial_loss=2.975597
# [INFO] Step 1_325: discriminator_loss=0.351697, adversarial_loss=1.729867
# [INFO] Step 1_350: discriminator_loss=0.371082, adversarial_loss=1.882845
# [INFO] Step 1_375: discriminator_loss=1.124366, adversarial_loss=1.495434
# [INFO] Step 1_400: discriminator_loss=0.456411, adversarial_loss=0.911060
# [INFO] Step 1_425: discriminator_loss=0.389182, adversarial_loss=1.640545
# [INFO] Step 1_450: discriminator_loss=0.371985, adversarial_loss=2.114936
# [INFO] Step 1_475: discriminator_loss=0.463485, adversarial_loss=1.309233
# [INFO] Step 1_500: discriminator_loss=0.453580, adversarial_loss=1.263971
# [INFO] Step 1_525: discriminator_loss=0.507593, adversarial_loss=0.948736
# [INFO] Step 1_545: discriminator_loss=0.364468, adversarial_loss=1.788347
# [INFO] starting epoch 2 of 50...
# [INFO] Step 2_0: discriminator_loss=0.419867, adversarial_loss=1.427904
# [INFO] Step 2_25: discriminator_loss=0.420363, adversarial_loss=1.451453
# [INFO] Step 2_50: discriminator_loss=0.696380, adversarial_loss=0.280972
# [INFO] Step 2_75: discriminator_loss=0.418904, adversarial_loss=1.470742
# [INFO] Step 7_100: discriminator_loss=0.625183, adversarial_loss=1.165764
# [INFO] Step 7_125: discriminator_loss=0.652775, adversarial_loss=1.134864
# [INFO] Step 7_150: discriminator_loss=0.678741, adversarial_loss=0.690538
# [INFO] Step 7_175: discriminator_loss=0.666691, adversarial_loss=0.935108
# [INFO] Step 7_200: discriminator_loss=0.604985, adversarial_loss=0.843178
# [INFO] Step 7_225: discriminator_loss=0.604478, adversarial_loss=0.877478
# [INFO] Step 7_250: discriminator_loss=0.652717, adversarial_loss=0.800725
# [INFO] Step 7_275: discriminator_loss=0.573923, adversarial_loss=1.008233
# [INFO] Step 7_300: discriminator_loss=0.598648, adversarial_loss=0.823640
# [INFO] Step 7_325: discriminator_loss=0.610088, adversarial_loss=1.102529
# [INFO] Step 7_350: discriminator_loss=0.592418, adversarial_loss=0.975664
# [INFO] Step 7_375: discriminator_loss=0.599163, adversarial_loss=0.750126
# [INFO] Step 7_400: discriminator_loss=0.631860, adversarial_loss=0.663028
# [INFO] Step 7_425: discriminator_loss=0.629875, adversarial_loss=0.885266
# [INFO] Step 7_450: discriminator_loss=0.593268, adversarial_loss=0.898054
# [INFO] Step 7_475: discriminator_loss=0.603257, adversarial_loss=0.964265
# [INFO] Step 7_500: discriminator_loss=0.624919, adversarial_loss=0.914915
# [INFO] Step 7_525: discriminator_loss=0.615200, adversarial_loss=0.801501
# [INFO] Step 7_545: discriminator_loss=0.493855, adversarial_loss=1.580016
# [INFO] starting epoch 8 of 50...
# [INFO] Step 8_0: discriminator_loss=0.611503, adversarial_loss=0.974200
# [INFO] Step 8_25: discriminator_loss=0.592278, adversarial_loss=0.823270
# [INFO] Step 8_50: discriminator_loss=0.568015, adversarial_loss=0.915667
# [INFO] Step 8_75: discriminator_loss=0.598425, adversarial_loss=0.919277
# [INFO] Step 8_100: discriminator_loss=0.606241, adversarial_loss=1.089043
# [INFO] Step 8_125: discriminator_loss=0.637422, adversarial_loss=0.857127
# [INFO] Step 8_150: discriminator_loss=0.576514, adversarial_loss=0.734864
# [INFO] Step 8_175: discriminator_loss=0.741135, adversarial_loss=1.225957
# [INFO] Step 8_200: discriminator_loss=0.622874, adversarial_loss=0.784813
# [INFO] Step 8_225: discriminator_loss=0.606540, adversarial_loss=0.768957
# [INFO] Step 8_250: discriminator_loss=0.664791, adversarial_loss=0.594273
# [INFO] Step 8_275: discriminator_loss=0.567656, adversarial_loss=1.036377
# [INFO] Step 8_300: discriminator_loss=0.595993, adversarial_loss=0.870559
# [INFO] Step 8_325: discriminator_loss=0.617736, adversarial_loss=1.214611
# [INFO] Step 8_350: discriminator_loss=0.606828, adversarial_loss=0.923440
# [INFO] Step 8_375: discriminator_loss=0.602734, adversarial_loss=1.006085
# [INFO] Step 8_400: discriminator_loss=0.606561, adversarial_loss=0.827248
# [INFO] Step 8_425: discriminator_loss=0.616540, adversarial_loss=0.896163
# [INFO] Step 8_450: discriminator_loss=0.594797, adversarial_loss=0.924743
# [INFO] Step 19_545: discriminator_loss=0.468011, adversarial_loss=1.306187
# [INFO] starting epoch 20 of 50...
# [INFO] Step 20_0: discriminator_loss=0.592336, adversarial_loss=1.114904
# [INFO] Step 20_100: discriminator_loss=0.608727, adversarial_loss=1.235093
# [INFO] Step 20_200: discriminator_loss=0.549825, adversarial_loss=0.979044
# [INFO] Step 20_300: discriminator_loss=0.555754, adversarial_loss=0.980732
# [INFO] Step 20_400: discriminator_loss=0.538461, adversarial_loss=0.876607
# [INFO] Step 20_500: discriminator_loss=0.564434, adversarial_loss=0.906483
# [INFO] Step 20_545: discriminator_loss=0.486150, adversarial_loss=1.358058
# [INFO] starting epoch 21 of 50...
# [INFO] Step 21_0: discriminator_loss=0.579698, adversarial_loss=0.897067
# [INFO] Step 21_100: discriminator_loss=0.568458, adversarial_loss=1.147128
# [INFO] Step 21_200: discriminator_loss=0.590860, adversarial_loss=0.776197
# [INFO] Step 21_300: discriminator_loss=0.560422, adversarial_loss=0.873157
# [INFO] Step 21_400: discriminator_loss=0.567349, adversarial_loss=0.886649
# [INFO] Step 21_500: discriminator_loss=0.565934, adversarial_loss=0.767514
# [INFO] Step 21_545: discriminator_loss=0.473469, adversarial_loss=1.736807
# [INFO] starting epoch 22 of 50...
# [INFO] Step 22_0: discriminator_loss=0.656911, adversarial_loss=0.933093
# [INFO] Step 22_100: discriminator_loss=0.585038, adversarial_loss=1.237470
# [INFO] Step 22_200: discriminator_loss=0.560994, adversarial_loss=0.913550
# [INFO] Step 22_300: discriminator_loss=0.548296, adversarial_loss=1.099599
# [INFO] Step 22_400: discriminator_loss=0.582914, adversarial_loss=1.528874
# [INFO] Step 22_500: discriminator_loss=0.551444, adversarial_loss=0.891282
# [INFO] Step 22_545: discriminator_loss=0.453975, adversarial_loss=1.675633
# [INFO] starting epoch 23 of 50...
# [INFO] Step 23_0: discriminator_loss=0.615568, adversarial_loss=1.082700
# [INFO] Step 23_100: discriminator_loss=0.559122, adversarial_loss=1.181358
# [INFO] Step 23_200: discriminator_loss=0.577791, adversarial_loss=0.754150
# [INFO] Step 23_300: discriminator_loss=0.541387, adversarial_loss=0.907143
# [INFO] Step 23_400: discriminator_loss=0.542435, adversarial_loss=1.082232
# [INFO] Step 23_500: discriminator_loss=0.552304, adversarial_loss=0.838288
# [INFO] Step 23_545: discriminator_loss=0.433140, adversarial_loss=1.598045
# [INFO] starting epoch 24 of 50...
# [INFO] Step 24_0: discriminator_loss=0.554894, adversarial_loss=1.069142
# [INFO] Step 24_100: discriminator_loss=0.610842, adversarial_loss=1.709773
# [INFO] Step 24_200: discriminator_loss=0.547781, adversarial_loss=1.025453
# [INFO] Step 24_300: discriminator_loss=0.537147, adversarial_loss=0.841385
# [INFO] Step 24_400: discriminator_loss=0.536291, adversarial_loss=0.983606
# [INFO] Step 24_500: discriminator_loss=0.542025, adversarial_loss=0.809988
# [INFO] Step 24_545: discriminator_loss=0.437956, adversarial_loss=1.559634
# [INFO] starting epoch 25 of 50...
# [INFO] Step 25_0: discriminator_loss=0.613209, adversarial_loss=1.045547
# [INFO] Step 25_100: discriminator_loss=0.537510, adversarial_loss=1.281625
# [INFO] Step 25_200: discriminator_loss=0.510074, adversarial_loss=1.066148
# [INFO] Step 25_300: discriminator_loss=0.540648, adversarial_loss=1.223579
# [INFO] Step 25_400: discriminator_loss=0.528850, adversarial_loss=0.961795
# [INFO] Step 25_500: discriminator_loss=0.538559, adversarial_loss=1.240812
# [INFO] Step 25_545: discriminator_loss=0.425492, adversarial_loss=1.604310
# [INFO] starting epoch 26 of 50...
# [INFO] Step 26_0: discriminator_loss=0.553140, adversarial_loss=0.834387
# [INFO] Step 26_100: discriminator_loss=0.565671, adversarial_loss=1.351397
# [INFO] Step 26_200: discriminator_loss=0.516207, adversarial_loss=0.743087
# [INFO] Step 26_300: discriminator_loss=0.488986, adversarial_loss=1.090421
# [INFO] Step 26_400: discriminator_loss=0.557430, adversarial_loss=1.799334
# [INFO] Step 26_500: discriminator_loss=0.543860, adversarial_loss=1.021745
# [INFO] Step 26_545: discriminator_loss=0.500061, adversarial_loss=2.101521
# [INFO] starting epoch 27 of 50...
# [INFO] Step 27_0: discriminator_loss=0.661615, adversarial_loss=1.184165
# [INFO] Step 27_100: discriminator_loss=0.573413, adversarial_loss=1.415463
# [INFO] Step 27_200: discriminator_loss=0.546901, adversarial_loss=1.057339
# [INFO] Step 27_300: discriminator_loss=0.540690, adversarial_loss=1.357324
# [INFO] Step 27_400: discriminator_loss=0.482578, adversarial_loss=1.181941
# [INFO] Step 27_500: discriminator_loss=0.509740, adversarial_loss=1.178492
# [INFO] Step 27_545: discriminator_loss=0.402413, adversarial_loss=1.721095
# [INFO] starting epoch 28 of 50...
# [INFO] Step 28_0: discriminator_loss=0.573851, adversarial_loss=1.103967
# [INFO] Step 28_100: discriminator_loss=0.550501, adversarial_loss=1.427495
# [INFO] Step 28_200: discriminator_loss=0.557184, adversarial_loss=1.327328
# [INFO] Step 28_300: discriminator_loss=0.485114, adversarial_loss=1.080187
# [INFO] Step 28_400: discriminator_loss=0.598037, adversarial_loss=0.686865
# [INFO] Step 28_500: discriminator_loss=0.502362, adversarial_loss=1.010088
# [INFO] Step 28_545: discriminator_loss=0.428591, adversarial_loss=1.992907
# [INFO] starting epoch 29 of 50...
# [INFO] Step 29_0: discriminator_loss=0.599825, adversarial_loss=0.682415
# [INFO] Step 29_100: discriminator_loss=0.553880, adversarial_loss=1.464760
# [INFO] Step 29_200: discriminator_loss=0.552422, adversarial_loss=1.552516
# [INFO] Step 29_300: discriminator_loss=0.501266, adversarial_loss=1.101139
# [INFO] Step 29_400: discriminator_loss=0.526566, adversarial_loss=1.632809
# [INFO] Step 29_500: discriminator_loss=0.502354, adversarial_loss=1.159565
# [INFO] Step 29_545: discriminator_loss=0.410219, adversarial_loss=1.785956
# [INFO] starting epoch 30 of 50...
# [INFO] Step 30_0: discriminator_loss=0.582561, adversarial_loss=0.961227
# [INFO] Step 30_100: discriminator_loss=0.544760, adversarial_loss=1.222483
# [INFO] Step 30_200: discriminator_loss=0.510754, adversarial_loss=0.830937
# [INFO] Step 30_300: discriminator_loss=0.477666, adversarial_loss=1.307725
# [INFO] Step 30_400: discriminator_loss=0.505296, adversarial_loss=1.460325
# [INFO] Step 30_500: discriminator_loss=0.507222, adversarial_loss=0.894732
# [INFO] Step 30_545: discriminator_loss=0.428733, adversarial_loss=1.332712
# [INFO] starting epoch 31 of 50...
# [INFO] Step 31_0: discriminator_loss=0.530155, adversarial_loss=1.046466
# [INFO] Step 31_100: discriminator_loss=0.508118, adversarial_loss=1.262601
# [INFO] Step 31_200: discriminator_loss=0.521913, adversarial_loss=1.162841
# [INFO] Step 31_300: discriminator_loss=0.471481, adversarial_loss=1.239775
# [INFO] Step 31_400: discriminator_loss=0.479381, adversarial_loss=1.262871
# [INFO] Step 31_500: discriminator_loss=0.481643, adversarial_loss=0.995762
# [INFO] Step 31_545: discriminator_loss=0.399103, adversarial_loss=1.715401
# [INFO] starting epoch 32 of 50...
# [INFO] Step 32_0: discriminator_loss=0.587802, adversarial_loss=1.079345
# [INFO] Step 32_100: discriminator_loss=0.501262, adversarial_loss=1.468068
# [INFO] Step 32_200: discriminator_loss=0.530491, adversarial_loss=0.858378
# [INFO] Step 32_300: discriminator_loss=0.442056, adversarial_loss=1.156271
# [INFO] Step 32_400: discriminator_loss=0.496877, adversarial_loss=1.026245
# [INFO] Step 32_500: discriminator_loss=0.514937, adversarial_loss=1.292558
# [INFO] Step 32_545: discriminator_loss=0.390982, adversarial_loss=1.671902
# [INFO] starting epoch 33 of 50...
# [INFO] Step 33_0: discriminator_loss=0.547119, adversarial_loss=1.307116
# [INFO] Step 33_100: discriminator_loss=0.544672, adversarial_loss=1.394766
# [INFO] Step 33_200: discriminator_loss=0.506402, adversarial_loss=1.123857
# [INFO] Step 33_300: discriminator_loss=0.462614, adversarial_loss=1.133767
# [INFO] Step 33_400: discriminator_loss=0.499014, adversarial_loss=1.580384
# [INFO] Step 33_500: discriminator_loss=0.515186, adversarial_loss=0.938833
# [INFO] Step 33_545: discriminator_loss=0.391525, adversarial_loss=1.998037
# [INFO] starting epoch 34 of 50...
# [INFO] Step 34_0: discriminator_loss=0.589456, adversarial_loss=1.046358
# [INFO] Step 34_100: discriminator_loss=0.529659, adversarial_loss=1.570559
# [INFO] Step 34_200: discriminator_loss=0.525141, adversarial_loss=0.899027
# [INFO] Step 34_300: discriminator_loss=0.491671, adversarial_loss=1.141900
# [INFO] Step 34_400: discriminator_loss=0.442668, adversarial_loss=1.079047
# [INFO] Step 34_500: discriminator_loss=0.457976, adversarial_loss=1.390470
# [INFO] Step 34_545: discriminator_loss=0.423193, adversarial_loss=2.006706
# [INFO] starting epoch 35 of 50...
# [INFO] Step 35_0: discriminator_loss=0.587236, adversarial_loss=0.955578
# [INFO] Step 35_100: discriminator_loss=0.560355, adversarial_loss=1.847868
# [INFO] Step 35_200: discriminator_loss=0.495681, adversarial_loss=1.247722
# [INFO] Step 35_300: discriminator_loss=0.464379, adversarial_loss=1.469627
# [INFO] Step 35_400: discriminator_loss=0.505018, adversarial_loss=1.505098
# [INFO] Step 35_500: discriminator_loss=0.480015, adversarial_loss=1.075977
# [INFO] Step 35_545: discriminator_loss=0.405435, adversarial_loss=1.837275
# [INFO] starting epoch 36 of 50...
# [INFO] Step 36_0: discriminator_loss=0.526832, adversarial_loss=1.178438
# [INFO] Step 36_100: discriminator_loss=0.501253, adversarial_loss=1.458014
# [INFO] Step 36_200: discriminator_loss=0.483224, adversarial_loss=1.131224
# [INFO] Step 36_300: discriminator_loss=0.451128, adversarial_loss=1.179243
# [INFO] Step 36_400: discriminator_loss=0.464007, adversarial_loss=1.263817
# [INFO] Step 36_500: discriminator_loss=0.477343, adversarial_loss=1.047410
# [INFO] Step 36_545: discriminator_loss=0.343644, adversarial_loss=1.891600
# [INFO] starting epoch 37 of 50...
# [INFO] Step 37_0: discriminator_loss=0.559308, adversarial_loss=1.276570
# [INFO] Step 37_100: discriminator_loss=0.511923, adversarial_loss=1.778593
# [INFO] Step 37_200: discriminator_loss=0.499891, adversarial_loss=0.997243
# [INFO] Step 37_300: discriminator_loss=0.461474, adversarial_loss=0.999273
# [INFO] Step 37_400: discriminator_loss=0.486002, adversarial_loss=1.433430
# [INFO] Step 37_500: discriminator_loss=0.469550, adversarial_loss=0.771316
# [INFO] Step 37_545: discriminator_loss=0.363849, adversarial_loss=2.330589
# [INFO] starting epoch 38 of 50...
# [INFO] Step 38_0: discriminator_loss=0.590691, adversarial_loss=0.873477
# [INFO] Step 38_100: discriminator_loss=0.513743, adversarial_loss=1.659497
# [INFO] Step 38_200: discriminator_loss=0.495988, adversarial_loss=1.595499
# [INFO] Step 38_300: discriminator_loss=0.407225, adversarial_loss=1.296946
# [INFO] Step 38_400: discriminator_loss=0.475838, adversarial_loss=1.215046
# [INFO] Step 38_500: discriminator_loss=0.475689, adversarial_loss=1.543150
# [INFO] Step 38_545: discriminator_loss=0.389655, adversarial_loss=1.798938
# [INFO] starting epoch 39 of 50...
# [INFO] Step 39_0: discriminator_loss=0.542795, adversarial_loss=1.191133
# [INFO] Step 39_100: discriminator_loss=0.512230, adversarial_loss=1.812806
# [INFO] Step 39_200: discriminator_loss=0.502795, adversarial_loss=1.094487
# [INFO] Step 39_300: discriminator_loss=0.437253, adversarial_loss=1.591016
# [INFO] Step 39_400: discriminator_loss=0.467348, adversarial_loss=1.101185
# [INFO] Step 39_500: discriminator_loss=0.438019, adversarial_loss=1.315800
# [INFO] Step 39_545: discriminator_loss=0.380541, adversarial_loss=1.809087
# [INFO] starting epoch 40 of 50...
# [INFO] Step 40_0: discriminator_loss=0.509295, adversarial_loss=1.180145
# [INFO] Step 40_100: discriminator_loss=0.460219, adversarial_loss=1.591964
# [INFO] Step 40_200: discriminator_loss=0.571600, adversarial_loss=0.598584
# [INFO] Step 40_300: discriminator_loss=0.468441, adversarial_loss=1.690247
# [INFO] Step 40_400: discriminator_loss=0.523623, adversarial_loss=2.486240
# [INFO] Step 40_500: discriminator_loss=0.453072, adversarial_loss=1.271131
# [INFO] Step 40_545: discriminator_loss=0.377454, adversarial_loss=2.432280
# [INFO] starting epoch 41 of 50...
# [INFO] Step 41_0: discriminator_loss=0.605798, adversarial_loss=1.104540
# [INFO] Step 41_100: discriminator_loss=0.534779, adversarial_loss=1.983226
# [INFO] Step 41_200: discriminator_loss=0.476321, adversarial_loss=0.836802
# [INFO] Step 41_300: discriminator_loss=0.455026, adversarial_loss=1.143316
# [INFO] Step 41_400: discriminator_loss=0.487717, adversarial_loss=1.300391
# [INFO] Step 41_500: discriminator_loss=0.459513, adversarial_loss=1.388998
# [INFO] Step 41_545: discriminator_loss=0.375824, adversarial_loss=1.572352
# [INFO] starting epoch 42 of 50...
# [INFO] Step 42_0: discriminator_loss=0.513427, adversarial_loss=1.300937
# [INFO] Step 42_100: discriminator_loss=0.522243, adversarial_loss=1.762316
# [INFO] Step 42_200: discriminator_loss=0.519709, adversarial_loss=1.820859
# [INFO] Step 42_300: discriminator_loss=0.434377, adversarial_loss=1.354434
# [INFO] Step 42_400: discriminator_loss=0.473355, adversarial_loss=1.256048
# [INFO] Step 42_500: discriminator_loss=0.470645, adversarial_loss=1.504266
# [INFO] Step 42_545: discriminator_loss=0.389087, adversarial_loss=2.294444
# [INFO] starting epoch 43 of 50...
# [INFO] Step 43_0: discriminator_loss=0.528009, adversarial_loss=0.940561
# [INFO] Step 43_100: discriminator_loss=0.471858, adversarial_loss=1.482471
# [INFO] Step 43_200: discriminator_loss=0.470384, adversarial_loss=1.094691
# [INFO] Step 43_300: discriminator_loss=0.428562, adversarial_loss=1.509243
# [INFO] Step 43_400: discriminator_loss=0.463208, adversarial_loss=1.750167
# [INFO] Step 43_500: discriminator_loss=0.437899, adversarial_loss=0.996666
# [INFO] Step 43_545: discriminator_loss=0.446434, adversarial_loss=2.818794
# [INFO] starting epoch 44 of 50...
# [INFO] Step 44_0: discriminator_loss=0.625041, adversarial_loss=1.254927
# [INFO] Step 44_100: discriminator_loss=0.490471, adversarial_loss=1.660625
# [INFO] Step 44_200: discriminator_loss=0.455093, adversarial_loss=1.260996
# [INFO] Step 44_300: discriminator_loss=0.471323, adversarial_loss=1.020383
# [INFO] Step 44_400: discriminator_loss=0.461908, adversarial_loss=1.327517
# [INFO] Step 44_500: discriminator_loss=0.492052, adversarial_loss=1.023108
# [INFO] Step 44_545: discriminator_loss=0.392771, adversarial_loss=1.687301
# [INFO] starting epoch 45 of 50...
# [INFO] Step 45_0: discriminator_loss=0.495750, adversarial_loss=1.153802
# [INFO] Step 45_100: discriminator_loss=0.495453, adversarial_loss=1.837868
# [INFO] Step 45_200: discriminator_loss=0.432800, adversarial_loss=1.358198
# [INFO] Step 45_300: discriminator_loss=0.435205, adversarial_loss=0.956253
# [INFO] Step 45_400: discriminator_loss=0.469988, adversarial_loss=1.301669
# [INFO] Step 45_500: discriminator_loss=0.480843, adversarial_loss=1.536093
# [INFO] Step 45_545: discriminator_loss=0.358272, adversarial_loss=1.962752
# [INFO] starting epoch 46 of 50...
# [INFO] Step 46_0: discriminator_loss=0.481826, adversarial_loss=1.230667
# [INFO] Step 46_100: discriminator_loss=0.487712, adversarial_loss=1.907885
# [INFO] Step 46_200: discriminator_loss=0.476644, adversarial_loss=1.013495
# [INFO] Step 46_300: discriminator_loss=0.425407, adversarial_loss=1.375358
# [INFO] Step 46_400: discriminator_loss=0.469412, adversarial_loss=1.121942
# [INFO] Step 46_500: discriminator_loss=0.465053, adversarial_loss=1.200060
# [INFO] Step 46_545: discriminator_loss=0.356687, adversarial_loss=2.067605
# [INFO] starting epoch 47 of 50...
# [INFO] Step 47_0: discriminator_loss=0.488512, adversarial_loss=1.296411
# [INFO] Step 47_100: discriminator_loss=0.524287, adversarial_loss=2.068730
# [INFO] Step 47_200: discriminator_loss=0.473645, adversarial_loss=1.791114
# [INFO] Step 47_300: discriminator_loss=0.415372, adversarial_loss=1.068923
# [INFO] Step 47_400: discriminator_loss=0.469294, adversarial_loss=1.102037
# [INFO] Step 47_500: discriminator_loss=0.456383, adversarial_loss=1.227554
# [INFO] Step 47_545: discriminator_loss=0.382711, adversarial_loss=2.349322
# [INFO] starting epoch 48 of 50...
# [INFO] Step 48_0: discriminator_loss=0.511438, adversarial_loss=0.980735
# [INFO] Step 48_100: discriminator_loss=0.473107, adversarial_loss=1.951497
# [INFO] Step 48_200: discriminator_loss=0.519760, adversarial_loss=0.691862
# [INFO] Step 48_300: discriminator_loss=0.422650, adversarial_loss=1.310883
# [INFO] Step 48_400: discriminator_loss=0.438069, adversarial_loss=1.457327
# [INFO] Step 48_500: discriminator_loss=0.454660, adversarial_loss=1.622985
# [INFO] Step 48_545: discriminator_loss=0.409287, adversarial_loss=1.929114
# [INFO] starting epoch 49 of 50...
# [INFO] Step 49_0: discriminator_loss=0.454408, adversarial_loss=1.059036
# [INFO] Step 49_100: discriminator_loss=0.450503, adversarial_loss=1.895600
# [INFO] Step 49_200: discriminator_loss=0.481880, adversarial_loss=0.876099
# [INFO] Step 49_300: discriminator_loss=0.445913, adversarial_loss=1.276498
# [INFO] Step 49_400: discriminator_loss=0.431660, adversarial_loss=1.442434
# [INFO] Step 49_500: discriminator_loss=0.453304, adversarial_loss=1.749338
# [INFO] Step 49_545: discriminator_loss=0.379339, adversarial_loss=1.601145
# [INFO] starting epoch 50 of 50...
# [INFO] Step 50_0: discriminator_loss=0.455920, adversarial_loss=1.489177
# [INFO] Step 50_100: discriminator_loss=0.447137, adversarial_loss=1.581933
# [INFO] Step 50_200: discriminator_loss=0.477259, adversarial_loss=0.768808
# [INFO] Step 50_300: discriminator_loss=0.386691, adversarial_loss=1.189798
# [INFO] Step 50_400: discriminator_loss=0.483153, adversarial_loss=0.882905
# [INFO] Step 50_500: discriminator_loss=0.424871, adversarial_loss=1.500068
# [INFO] Step 50_545: discriminator_loss=0.594729, adversarial_loss=1.113182
# [INFO] done.
