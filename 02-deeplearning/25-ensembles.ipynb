# %% [markdown]
# **Use GPU: Runtime -> Change runtime type -> GPU (Hardware Accelerator)**

# %% [markdown]
# Setup

# %%
# !cat ~/.keras/keras.json
# Out:
# {
#     "epsilon": 1e-07,
#     "floatx": "float32",
#     "image_data_format": "channels_last",
#     "backend": "tensorflow"
# }

# %% [markdown]
# Mini-VGGNet

# %%
# import the necessary packages
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras import backend as K

# %%
class MiniVGGNet:
	@staticmethod
	def build(width, height, depth, classes):
		# initialize the model along with the input shape to be
		# "channels last" and the channels dimension itself
		model = Sequential()
		inputShape = (height, width, depth)
		chanDim = -1

		# if we are using "channels first", update the input shape
		# and channels dimension
		if K.image_data_format() == "channels_first":
			inputShape = (depth, height, width)
			chanDim = 1

		# first CONV => RELU => CONV => RELU => POOL layer set
		model.add(Conv2D(32, (3, 3), padding="same", input_shape=inputShape))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(Conv2D(32, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(MaxPooling2D(pool_size=(2, 2)))
		model.add(Dropout(0.25))

		# second CONV => RELU => CONV => RELU => POOL layer set
		model.add(Conv2D(64, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(Conv2D(64, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(MaxPooling2D(pool_size=(2, 2)))
		model.add(Dropout(0.25))

		# first (and only) set of FC => RELU layers
		model.add(Flatten())
		model.add(Dense(512))
		model.add(Activation("relu"))
		model.add(BatchNormalization())
		model.add(Dropout(0.5))

		# softmax classifier
		model.add(Dense(classes))
		model.add(Activation("softmax"))

		# return the constructed network architecture
		return model

# %% [markdown]
# Train Ensemble (MiniVGGNet) w/ CIFAR10 + Data Aug

# %%
# import the necessary packages
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import SGD
from keras.datasets import cifar10
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
def train_ensemble(output_filename, models_folder, num_models=5):
    # load the training and testing data, then scale it into the
    # range [0, 1]
    ((trainX, trainY), (testX, testY)) = cifar10.load_data()
    trainX = trainX.astype("float") / 255.0
    testX = testX.astype("float") / 255.0

    # convert the labels from integers to vectors
    lb = LabelBinarizer()
    trainY = lb.fit_transform(trainY)
    testY = lb.transform(testY)

    # initialize the label names for the CIFAR-10 dataset
    labelNames = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

    # construct the image generator for data augmentation
    aug = ImageDataGenerator(rotation_range=10, width_shift_range=0.1,
        height_shift_range=0.1, horizontal_flip=True,
        fill_mode="nearest")

    # loop over the number of models to train
    for i in np.arange(0, num_models):
        # initialize the optimizer and model
        print("[INFO] training model {}/{}".format(i + 1, num_models))
        opt = SGD(lr=0.01, decay=0.01 / 40, momentum=0.9, nesterov=True)
        model = MiniVGGNet.build(width=32, height=32, depth=3, classes=10)
        model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])

        # train the network
        H = model.fit_generator(aug.flow(trainX, trainY, batch_size=64),
            validation_data=(testX, testY), epochs=40,
            steps_per_epoch=len(trainX) // 64, verbose=1)

        # save the model to disk
        p = [models_folder, "model_{}.model".format(i)]
        model.save(os.path.sep.join(p))

        # evaluate the network
        predictions = model.predict(testX, batch_size=64)
        report = classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=labelNames)

        # save the classification report to file
        p = [output_filename, "model_{}.txt".format(i)]
        f = open(os.path.sep.join(p), "w")
        f.write(report)
        f.close()

        # plot the training loss and accuracy
        p = [output_filename, "model_{}.png".format(i)]
        plt.figure()
        plt.plot(np.arange(0, 40), H.history["loss"], label="train_loss")
        plt.plot(np.arange(0, 40), H.history["val_loss"], label="val_loss")
        plt.plot(np.arange(0, 40), H.history["accuracy"], label="train_accuracy")
        plt.plot(np.arange(0, 40), H.history["val_accuracy"], label="val_accuracy")
        plt.title("Training Loss and Accuracy for model {}".format(i))
        plt.xlabel("Epoch #")
        plt.ylabel("Loss/Accuracy")
        plt.legend()
        plt.savefig(os.path.sep.join(p))
        plt.close()

# %%
train_ensemble(output_filename="drive/MyDrive/pyimagesearch/output/25-ensembles/output", models_folder="drive/MyDrive/pyimagesearch/output/25-ensembles/models")
# Out:
# [INFO] training model 1/5
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/40
# 781/781 [==============================] - 28s 35ms/step - loss: 2.0677 - accuracy: 0.3459 - val_loss: 1.4490 - val_accuracy: 0.4999
# Epoch 2/40
# 781/781 [==============================] - 27s 35ms/step - loss: 1.3978 - accuracy: 0.5150 - val_loss: 1.2156 - val_accuracy: 0.5854
# Epoch 3/40
# 781/781 [==============================] - 26s 34ms/step - loss: 1.2044 - accuracy: 0.5746 - val_loss: 1.0826 - val_accuracy: 0.6338
# Epoch 4/40
# 781/781 [==============================] - 27s 34ms/step - loss: 1.0739 - accuracy: 0.6222 - val_loss: 1.0167 - val_accuracy: 0.6615
# Epoch 5/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.9998 - accuracy: 0.6486 - val_loss: 1.0232 - val_accuracy: 0.6643
# Epoch 6/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.9489 - accuracy: 0.6657 - val_loss: 0.8523 - val_accuracy: 0.7112
# Epoch 7/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.9015 - accuracy: 0.6829 - val_loss: 0.8442 - val_accuracy: 0.7162
# Epoch 8/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.8775 - accuracy: 0.6895 - val_loss: 0.8234 - val_accuracy: 0.7186
# Epoch 9/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.8484 - accuracy: 0.7023 - val_loss: 0.8826 - val_accuracy: 0.7079
# Epoch 10/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.8258 - accuracy: 0.7078 - val_loss: 0.8793 - val_accuracy: 0.7111
# Epoch 11/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7937 - accuracy: 0.7188 - val_loss: 0.7484 - val_accuracy: 0.7442
# Epoch 12/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7777 - accuracy: 0.7251 - val_loss: 0.7245 - val_accuracy: 0.7517
# Epoch 13/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7559 - accuracy: 0.7340 - val_loss: 0.7200 - val_accuracy: 0.7519
# Epoch 14/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7562 - accuracy: 0.7334 - val_loss: 0.7403 - val_accuracy: 0.7488
# Epoch 15/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7523 - accuracy: 0.7337 - val_loss: 0.7657 - val_accuracy: 0.7429
# Epoch 16/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7249 - accuracy: 0.7474 - val_loss: 0.6880 - val_accuracy: 0.7662
# Epoch 17/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7160 - accuracy: 0.7486 - val_loss: 0.6657 - val_accuracy: 0.7716
# Epoch 18/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6997 - accuracy: 0.7532 - val_loss: 0.6440 - val_accuracy: 0.7799
# Epoch 19/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7009 - accuracy: 0.7515 - val_loss: 0.6684 - val_accuracy: 0.7720
# Epoch 20/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6894 - accuracy: 0.7560 - val_loss: 0.7093 - val_accuracy: 0.7595
# Epoch 21/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6788 - accuracy: 0.7606 - val_loss: 0.7606 - val_accuracy: 0.7479
# Epoch 22/40
# 781/781 [==============================] - 28s 36ms/step - loss: 0.6798 - accuracy: 0.7602 - val_loss: 0.6938 - val_accuracy: 0.7659
# Epoch 23/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6566 - accuracy: 0.7710 - val_loss: 0.7026 - val_accuracy: 0.7607
# Epoch 24/40
# 781/781 [==============================] - 28s 35ms/step - loss: 0.6574 - accuracy: 0.7690 - val_loss: 0.6660 - val_accuracy: 0.7722
# Epoch 25/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6560 - accuracy: 0.7693 - val_loss: 0.6275 - val_accuracy: 0.7848
# Epoch 26/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6496 - accuracy: 0.7707 - val_loss: 0.6307 - val_accuracy: 0.7840
# Epoch 27/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6397 - accuracy: 0.7751 - val_loss: 0.6622 - val_accuracy: 0.7768
# Epoch 28/40
# 781/781 [==============================] - 28s 35ms/step - loss: 0.6450 - accuracy: 0.7761 - val_loss: 0.6165 - val_accuracy: 0.7929
# Epoch 29/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6403 - accuracy: 0.7757 - val_loss: 0.5810 - val_accuracy: 0.8038
# Epoch 30/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6336 - accuracy: 0.7782 - val_loss: 0.6024 - val_accuracy: 0.7960
# Epoch 31/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6298 - accuracy: 0.7798 - val_loss: 0.6390 - val_accuracy: 0.7817
# Epoch 32/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6291 - accuracy: 0.7802 - val_loss: 0.5849 - val_accuracy: 0.8005
# Epoch 33/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6194 - accuracy: 0.7837 - val_loss: 0.6125 - val_accuracy: 0.7920
# Epoch 34/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6167 - accuracy: 0.7853 - val_loss: 0.6370 - val_accuracy: 0.7824
# Epoch 35/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6116 - accuracy: 0.7863 - val_loss: 0.5882 - val_accuracy: 0.8005
# Epoch 36/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6074 - accuracy: 0.7888 - val_loss: 0.6229 - val_accuracy: 0.7901
# Epoch 37/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6072 - accuracy: 0.7898 - val_loss: 0.5842 - val_accuracy: 0.8018
# Epoch 38/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.5987 - accuracy: 0.7897 - val_loss: 0.5771 - val_accuracy: 0.8052
# Epoch 39/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5950 - accuracy: 0.7906 - val_loss: 0.5902 - val_accuracy: 0.8023
# Epoch 40/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5964 - accuracy: 0.7905 - val_loss: 0.6158 - val_accuracy: 0.7922
# INFO:tensorflow:Assets written to: drive/MyDrive/pyimagesearch/output/25-ensembles/model_0.model/assets
# [INFO] training model 2/5
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/40
# 781/781 [==============================] - 28s 35ms/step - loss: 2.0866 - accuracy: 0.3399 - val_loss: 1.3232 - val_accuracy: 0.5273
# Epoch 2/40
# 781/781 [==============================] - 27s 34ms/step - loss: 1.4383 - accuracy: 0.4956 - val_loss: 1.1999 - val_accuracy: 0.5800
# Epoch 3/40
# 781/781 [==============================] - 27s 34ms/step - loss: 1.2150 - accuracy: 0.5710 - val_loss: 1.2763 - val_accuracy: 0.5849
# Epoch 4/40
# 781/781 [==============================] - 27s 34ms/step - loss: 1.1004 - accuracy: 0.6060 - val_loss: 1.0320 - val_accuracy: 0.6368
# Epoch 5/40
# 781/781 [==============================] - 27s 34ms/step - loss: 1.0055 - accuracy: 0.6427 - val_loss: 1.7466 - val_accuracy: 0.4701
# Epoch 6/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.9771 - accuracy: 0.6542 - val_loss: 0.9005 - val_accuracy: 0.6902
# Epoch 7/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.9188 - accuracy: 0.6721 - val_loss: 0.7839 - val_accuracy: 0.7345
# Epoch 8/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.8866 - accuracy: 0.6842 - val_loss: 0.8028 - val_accuracy: 0.7289
# Epoch 9/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.8634 - accuracy: 0.6967 - val_loss: 0.8150 - val_accuracy: 0.7263
# Epoch 10/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.8349 - accuracy: 0.7062 - val_loss: 0.7276 - val_accuracy: 0.7525
# Epoch 11/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.8031 - accuracy: 0.7195 - val_loss: 0.7408 - val_accuracy: 0.7486
# Epoch 12/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7868 - accuracy: 0.7242 - val_loss: 0.8015 - val_accuracy: 0.7304
# Epoch 13/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7700 - accuracy: 0.7255 - val_loss: 0.7601 - val_accuracy: 0.7437
# Epoch 14/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.7628 - accuracy: 0.7316 - val_loss: 0.7854 - val_accuracy: 0.7374
# Epoch 15/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7531 - accuracy: 0.7355 - val_loss: 0.7168 - val_accuracy: 0.7588
# Epoch 16/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.7336 - accuracy: 0.7450 - val_loss: 0.7255 - val_accuracy: 0.7577
# Epoch 17/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7191 - accuracy: 0.7464 - val_loss: 0.7451 - val_accuracy: 0.7525
# Epoch 18/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.7064 - accuracy: 0.7508 - val_loss: 0.7082 - val_accuracy: 0.7646
# Epoch 19/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7080 - accuracy: 0.7512 - val_loss: 0.7208 - val_accuracy: 0.7633
# Epoch 20/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.6900 - accuracy: 0.7562 - val_loss: 0.6586 - val_accuracy: 0.7794
# Epoch 21/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.6778 - accuracy: 0.7607 - val_loss: 0.6759 - val_accuracy: 0.7737
# Epoch 22/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.6793 - accuracy: 0.7584 - val_loss: 0.6158 - val_accuracy: 0.7892
# Epoch 23/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6723 - accuracy: 0.7652 - val_loss: 0.6943 - val_accuracy: 0.7666
# Epoch 24/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6626 - accuracy: 0.7675 - val_loss: 0.6270 - val_accuracy: 0.7855
# Epoch 25/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6637 - accuracy: 0.7693 - val_loss: 0.6717 - val_accuracy: 0.7756
# Epoch 26/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6500 - accuracy: 0.7689 - val_loss: 0.7014 - val_accuracy: 0.7658
# Epoch 27/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6468 - accuracy: 0.7732 - val_loss: 0.6532 - val_accuracy: 0.7823
# Epoch 28/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6443 - accuracy: 0.7754 - val_loss: 0.6388 - val_accuracy: 0.7841
# Epoch 29/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6453 - accuracy: 0.7734 - val_loss: 0.6096 - val_accuracy: 0.7941
# Epoch 30/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6282 - accuracy: 0.7793 - val_loss: 0.6141 - val_accuracy: 0.7903
# Epoch 31/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6286 - accuracy: 0.7794 - val_loss: 0.6980 - val_accuracy: 0.7673
# Epoch 32/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.6143 - accuracy: 0.7845 - val_loss: 0.6474 - val_accuracy: 0.7830
# Epoch 33/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.6168 - accuracy: 0.7862 - val_loss: 0.5804 - val_accuracy: 0.8010
# Epoch 34/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6172 - accuracy: 0.7815 - val_loss: 0.6097 - val_accuracy: 0.7891
# Epoch 35/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6082 - accuracy: 0.7859 - val_loss: 0.6193 - val_accuracy: 0.7915
# Epoch 36/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6083 - accuracy: 0.7860 - val_loss: 0.6571 - val_accuracy: 0.7787
# Epoch 37/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.5962 - accuracy: 0.7920 - val_loss: 0.6461 - val_accuracy: 0.7813
# Epoch 38/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6050 - accuracy: 0.7865 - val_loss: 0.6455 - val_accuracy: 0.7828
# Epoch 39/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.5975 - accuracy: 0.7916 - val_loss: 0.6558 - val_accuracy: 0.7836
# Epoch 40/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.5942 - accuracy: 0.7933 - val_loss: 0.5847 - val_accuracy: 0.8036
# INFO:tensorflow:Assets written to: drive/MyDrive/pyimagesearch/output/25-ensembles/model_1.model/assets
# [INFO] training model 3/5
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/40
# 781/781 [==============================] - 28s 34ms/step - loss: 2.0968 - accuracy: 0.3366 - val_loss: 1.2008 - val_accuracy: 0.5669
# Epoch 2/40
# 781/781 [==============================] - 26s 34ms/step - loss: 1.4027 - accuracy: 0.5092 - val_loss: 1.1693 - val_accuracy: 0.5998
# Epoch 3/40
# 781/781 [==============================] - 26s 34ms/step - loss: 1.2037 - accuracy: 0.5728 - val_loss: 1.0456 - val_accuracy: 0.6398
# Epoch 4/40
# 781/781 [==============================] - 27s 34ms/step - loss: 1.0862 - accuracy: 0.6157 - val_loss: 0.9204 - val_accuracy: 0.6762
# Epoch 5/40
# 781/781 [==============================] - 27s 34ms/step - loss: 1.0079 - accuracy: 0.6427 - val_loss: 0.8358 - val_accuracy: 0.7075
# Epoch 6/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.9544 - accuracy: 0.6658 - val_loss: 0.9063 - val_accuracy: 0.6912
# Epoch 7/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.8979 - accuracy: 0.6842 - val_loss: 0.8782 - val_accuracy: 0.7022
# Epoch 8/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.8605 - accuracy: 0.6960 - val_loss: 0.7997 - val_accuracy: 0.7248
# Epoch 9/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.8460 - accuracy: 0.7031 - val_loss: 0.9139 - val_accuracy: 0.6928
# Epoch 10/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.8329 - accuracy: 0.7115 - val_loss: 0.7517 - val_accuracy: 0.7431
# Epoch 11/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.8093 - accuracy: 0.7148 - val_loss: 0.7680 - val_accuracy: 0.7413
# Epoch 12/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7939 - accuracy: 0.7217 - val_loss: 0.7445 - val_accuracy: 0.7474
# Epoch 13/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.7878 - accuracy: 0.7230 - val_loss: 0.7842 - val_accuracy: 0.7415
# Epoch 14/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.7571 - accuracy: 0.7336 - val_loss: 0.7472 - val_accuracy: 0.7482
# Epoch 15/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7534 - accuracy: 0.7326 - val_loss: 0.6897 - val_accuracy: 0.7645
# Epoch 16/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.7455 - accuracy: 0.7395 - val_loss: 0.8037 - val_accuracy: 0.7311
# Epoch 17/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7247 - accuracy: 0.7446 - val_loss: 0.7098 - val_accuracy: 0.7616
# Epoch 18/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7130 - accuracy: 0.7495 - val_loss: 0.6872 - val_accuracy: 0.7663
# Epoch 19/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6976 - accuracy: 0.7578 - val_loss: 0.7140 - val_accuracy: 0.7644
# Epoch 20/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6947 - accuracy: 0.7565 - val_loss: 0.6665 - val_accuracy: 0.7788
# Epoch 21/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6897 - accuracy: 0.7574 - val_loss: 0.6543 - val_accuracy: 0.7821
# Epoch 22/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6959 - accuracy: 0.7560 - val_loss: 0.7417 - val_accuracy: 0.7543
# Epoch 23/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6866 - accuracy: 0.7595 - val_loss: 0.6386 - val_accuracy: 0.7845
# Epoch 24/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6789 - accuracy: 0.7650 - val_loss: 0.6425 - val_accuracy: 0.7846
# Epoch 25/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6737 - accuracy: 0.7629 - val_loss: 0.6895 - val_accuracy: 0.7722
# Epoch 26/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6639 - accuracy: 0.7662 - val_loss: 0.6855 - val_accuracy: 0.7666
# Epoch 27/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6571 - accuracy: 0.7679 - val_loss: 0.6232 - val_accuracy: 0.7926
# Epoch 28/40
# 781/781 [==============================] - 28s 35ms/step - loss: 0.6466 - accuracy: 0.7720 - val_loss: 0.6956 - val_accuracy: 0.7668
# Epoch 29/40
# 781/781 [==============================] - 28s 36ms/step - loss: 0.6512 - accuracy: 0.7719 - val_loss: 0.6981 - val_accuracy: 0.7640
# Epoch 30/40
# 781/781 [==============================] - 28s 35ms/step - loss: 0.6480 - accuracy: 0.7736 - val_loss: 0.6363 - val_accuracy: 0.7870
# Epoch 31/40
# 781/781 [==============================] - 28s 35ms/step - loss: 0.6386 - accuracy: 0.7773 - val_loss: 0.6087 - val_accuracy: 0.7938
# Epoch 32/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6357 - accuracy: 0.7774 - val_loss: 0.6032 - val_accuracy: 0.7986
# Epoch 33/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6367 - accuracy: 0.7797 - val_loss: 0.6105 - val_accuracy: 0.7937
# Epoch 34/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6206 - accuracy: 0.7841 - val_loss: 0.5910 - val_accuracy: 0.8008
# Epoch 35/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6326 - accuracy: 0.7777 - val_loss: 0.6434 - val_accuracy: 0.7857
# Epoch 36/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6158 - accuracy: 0.7847 - val_loss: 0.6411 - val_accuracy: 0.7859
# Epoch 37/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6207 - accuracy: 0.7813 - val_loss: 0.5993 - val_accuracy: 0.7953
# Epoch 38/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6128 - accuracy: 0.7858 - val_loss: 0.6154 - val_accuracy: 0.7940
# Epoch 39/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6070 - accuracy: 0.7868 - val_loss: 0.5709 - val_accuracy: 0.8076
# Epoch 40/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5980 - accuracy: 0.7917 - val_loss: 0.6363 - val_accuracy: 0.7846
# INFO:tensorflow:Assets written to: drive/MyDrive/pyimagesearch/output/25-ensembles/model_2.model/assets
# [INFO] training model 4/5
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/40
# 781/781 [==============================] - 28s 35ms/step - loss: 2.0788 - accuracy: 0.3455 - val_loss: 1.3536 - val_accuracy: 0.5377
# Epoch 2/40
# 781/781 [==============================] - 28s 35ms/step - loss: 1.3747 - accuracy: 0.5142 - val_loss: 1.1864 - val_accuracy: 0.5894
# Epoch 3/40
# 781/781 [==============================] - 27s 34ms/step - loss: 1.1936 - accuracy: 0.5798 - val_loss: 1.2512 - val_accuracy: 0.5821
# Epoch 4/40
# 781/781 [==============================] - 27s 34ms/step - loss: 1.0789 - accuracy: 0.6222 - val_loss: 1.0639 - val_accuracy: 0.6559
# Epoch 5/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.9882 - accuracy: 0.6513 - val_loss: 1.1458 - val_accuracy: 0.6416
# Epoch 6/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.9527 - accuracy: 0.6682 - val_loss: 0.8259 - val_accuracy: 0.7117
# Epoch 7/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.8969 - accuracy: 0.6814 - val_loss: 0.8244 - val_accuracy: 0.7182
# Epoch 8/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.8611 - accuracy: 0.6940 - val_loss: 0.9024 - val_accuracy: 0.6937
# Epoch 9/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.8354 - accuracy: 0.7050 - val_loss: 0.7361 - val_accuracy: 0.7448
# Epoch 10/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.8096 - accuracy: 0.7146 - val_loss: 0.7581 - val_accuracy: 0.7456
# Epoch 11/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.7866 - accuracy: 0.7209 - val_loss: 0.7114 - val_accuracy: 0.7545
# Epoch 12/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.7710 - accuracy: 0.7264 - val_loss: 0.6882 - val_accuracy: 0.7659
# Epoch 13/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.7572 - accuracy: 0.7359 - val_loss: 0.7328 - val_accuracy: 0.7509
# Epoch 14/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7564 - accuracy: 0.7338 - val_loss: 0.6844 - val_accuracy: 0.7626
# Epoch 15/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7403 - accuracy: 0.7401 - val_loss: 0.6882 - val_accuracy: 0.7631
# Epoch 16/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.7202 - accuracy: 0.7484 - val_loss: 0.6525 - val_accuracy: 0.7765
# Epoch 17/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7132 - accuracy: 0.7476 - val_loss: 0.6492 - val_accuracy: 0.7790
# Epoch 18/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6958 - accuracy: 0.7573 - val_loss: 0.7265 - val_accuracy: 0.7537
# Epoch 19/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.6925 - accuracy: 0.7564 - val_loss: 0.6545 - val_accuracy: 0.7748
# Epoch 20/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7023 - accuracy: 0.7534 - val_loss: 0.7211 - val_accuracy: 0.7600
# Epoch 21/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6683 - accuracy: 0.7662 - val_loss: 0.6100 - val_accuracy: 0.7910
# Epoch 22/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.6673 - accuracy: 0.7655 - val_loss: 0.6876 - val_accuracy: 0.7654
# Epoch 23/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6638 - accuracy: 0.7666 - val_loss: 0.6384 - val_accuracy: 0.7874
# Epoch 24/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6611 - accuracy: 0.7673 - val_loss: 0.6165 - val_accuracy: 0.7890
# Epoch 25/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6590 - accuracy: 0.7677 - val_loss: 0.6129 - val_accuracy: 0.7941
# Epoch 26/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6441 - accuracy: 0.7739 - val_loss: 0.6011 - val_accuracy: 0.7947
# Epoch 27/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6337 - accuracy: 0.7748 - val_loss: 0.5856 - val_accuracy: 0.8012
# Epoch 28/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.6427 - accuracy: 0.7721 - val_loss: 0.6314 - val_accuracy: 0.7837
# Epoch 29/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6271 - accuracy: 0.7799 - val_loss: 0.6137 - val_accuracy: 0.7914
# Epoch 30/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6310 - accuracy: 0.7785 - val_loss: 0.5842 - val_accuracy: 0.8016
# Epoch 31/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6240 - accuracy: 0.7807 - val_loss: 0.6068 - val_accuracy: 0.7960
# Epoch 32/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6235 - accuracy: 0.7816 - val_loss: 0.6067 - val_accuracy: 0.7950
# Epoch 33/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6091 - accuracy: 0.7880 - val_loss: 0.5840 - val_accuracy: 0.8001
# Epoch 34/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6120 - accuracy: 0.7832 - val_loss: 0.5946 - val_accuracy: 0.7973
# Epoch 35/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6123 - accuracy: 0.7884 - val_loss: 0.6187 - val_accuracy: 0.7916
# Epoch 36/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.6150 - accuracy: 0.7838 - val_loss: 0.6038 - val_accuracy: 0.7958
# Epoch 37/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.5967 - accuracy: 0.7919 - val_loss: 0.5576 - val_accuracy: 0.8099
# Epoch 38/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6058 - accuracy: 0.7882 - val_loss: 0.5637 - val_accuracy: 0.8094
# Epoch 39/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6007 - accuracy: 0.7883 - val_loss: 0.6004 - val_accuracy: 0.7963
# Epoch 40/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.6045 - accuracy: 0.7903 - val_loss: 0.6021 - val_accuracy: 0.7969
# INFO:tensorflow:Assets written to: drive/MyDrive/pyimagesearch/output/25-ensembles/model_3.model/assets
# [INFO] training model 5/5
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/40
# 781/781 [==============================] - 28s 35ms/step - loss: 2.1468 - accuracy: 0.3238 - val_loss: 1.4014 - val_accuracy: 0.5063
# Epoch 2/40
# 781/781 [==============================] - 27s 34ms/step - loss: 1.4526 - accuracy: 0.4890 - val_loss: 1.0913 - val_accuracy: 0.6161
# Epoch 3/40
# 781/781 [==============================] - 27s 34ms/step - loss: 1.2424 - accuracy: 0.5585 - val_loss: 1.1113 - val_accuracy: 0.6187
# Epoch 4/40
# 781/781 [==============================] - 26s 34ms/step - loss: 1.1172 - accuracy: 0.6026 - val_loss: 0.9138 - val_accuracy: 0.6811
# Epoch 5/40
# 781/781 [==============================] - 27s 34ms/step - loss: 1.0217 - accuracy: 0.6382 - val_loss: 0.8778 - val_accuracy: 0.6942
# Epoch 6/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.9638 - accuracy: 0.6584 - val_loss: 0.8726 - val_accuracy: 0.7001
# Epoch 7/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.9181 - accuracy: 0.6762 - val_loss: 0.9625 - val_accuracy: 0.6726
# Epoch 8/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.8863 - accuracy: 0.6868 - val_loss: 0.8740 - val_accuracy: 0.7021
# Epoch 9/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.8604 - accuracy: 0.6948 - val_loss: 0.7979 - val_accuracy: 0.7285
# Epoch 10/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.8360 - accuracy: 0.7042 - val_loss: 0.8324 - val_accuracy: 0.7151
# Epoch 11/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.8031 - accuracy: 0.7167 - val_loss: 0.7812 - val_accuracy: 0.7366
# Epoch 12/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.8026 - accuracy: 0.7154 - val_loss: 0.7271 - val_accuracy: 0.7475
# Epoch 13/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7840 - accuracy: 0.7248 - val_loss: 0.6829 - val_accuracy: 0.7635
# Epoch 14/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.7623 - accuracy: 0.7277 - val_loss: 0.7370 - val_accuracy: 0.7505
# Epoch 15/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.7605 - accuracy: 0.7304 - val_loss: 0.6786 - val_accuracy: 0.7646
# Epoch 16/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.7380 - accuracy: 0.7384 - val_loss: 0.6988 - val_accuracy: 0.7640
# Epoch 17/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7328 - accuracy: 0.7419 - val_loss: 0.6879 - val_accuracy: 0.7659
# Epoch 18/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.7219 - accuracy: 0.7474 - val_loss: 0.6768 - val_accuracy: 0.7736
# Epoch 19/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7148 - accuracy: 0.7492 - val_loss: 0.6515 - val_accuracy: 0.7738
# Epoch 20/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6984 - accuracy: 0.7535 - val_loss: 0.6779 - val_accuracy: 0.7703
# Epoch 21/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6920 - accuracy: 0.7595 - val_loss: 0.6608 - val_accuracy: 0.7759
# Epoch 22/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6764 - accuracy: 0.7621 - val_loss: 0.6694 - val_accuracy: 0.7747
# Epoch 23/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6706 - accuracy: 0.7658 - val_loss: 0.6529 - val_accuracy: 0.7769
# Epoch 24/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6653 - accuracy: 0.7655 - val_loss: 0.7014 - val_accuracy: 0.7669
# Epoch 25/40
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6705 - accuracy: 0.7655 - val_loss: 0.6867 - val_accuracy: 0.7694
# Epoch 26/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6654 - accuracy: 0.7678 - val_loss: 0.6595 - val_accuracy: 0.7783
# Epoch 27/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6554 - accuracy: 0.7669 - val_loss: 0.6779 - val_accuracy: 0.7736
# Epoch 28/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6509 - accuracy: 0.7732 - val_loss: 0.6695 - val_accuracy: 0.7740
# Epoch 29/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6507 - accuracy: 0.7706 - val_loss: 0.5923 - val_accuracy: 0.7954
# Epoch 30/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.6341 - accuracy: 0.7779 - val_loss: 0.6449 - val_accuracy: 0.7800
# Epoch 31/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6371 - accuracy: 0.7766 - val_loss: 0.6356 - val_accuracy: 0.7851
# Epoch 32/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6284 - accuracy: 0.7781 - val_loss: 0.6727 - val_accuracy: 0.7773
# Epoch 33/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6274 - accuracy: 0.7788 - val_loss: 0.6023 - val_accuracy: 0.7987
# Epoch 34/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6267 - accuracy: 0.7802 - val_loss: 0.6485 - val_accuracy: 0.7838
# Epoch 35/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6130 - accuracy: 0.7828 - val_loss: 0.5625 - val_accuracy: 0.8104
# Epoch 36/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6131 - accuracy: 0.7848 - val_loss: 0.5908 - val_accuracy: 0.8008
# Epoch 37/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.6162 - accuracy: 0.7826 - val_loss: 0.6093 - val_accuracy: 0.7953
# Epoch 38/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.6071 - accuracy: 0.7867 - val_loss: 0.6092 - val_accuracy: 0.7943
# Epoch 39/40
# 781/781 [==============================] - 26s 34ms/step - loss: 0.6056 - accuracy: 0.7874 - val_loss: 0.5655 - val_accuracy: 0.8068
# Epoch 40/40
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6020 - accuracy: 0.7893 - val_loss: 0.5960 - val_accuracy: 0.7973
# INFO:tensorflow:Assets written to: drive/MyDrive/pyimagesearch/output/25-ensembles/model_4.model/assets

# %% [markdown]
# Compare Individual vs Averaged Results

# %%
#ls output/
#grep 'weighted avg' output/*.txt

# %% [markdown]
# Evaluate Ensemble

# %%
# import the necessary packages
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report
from keras.models import load_model
from keras.datasets import cifar10
import numpy as np
import glob
import os

# %%
def evaluate_ensemble(models_folder):
    # load the testing data, then scale it into the range [0, 1]
    (testX, testY) = cifar10.load_data()[1]
    testX = testX.astype("float") / 255.0

    # initialize the label names for the CIFAR-10 dataset
    labelNames = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

    # convert the labels from integers to vectors
    lb = LabelBinarizer()
    testY = lb.fit_transform(testY)

    # construct the path used to collect the models then initialize the models list
    modelPaths = os.path.sep.join([models_folder, "*.model"])
    modelPaths = list(glob.glob(modelPaths))
    models = []

    # loop over the model paths, loading the model, and adding it to
    # the list of models
    for (i, modelPath) in enumerate(modelPaths):
        print("[INFO] loading model {}/{}".format(i + 1, len(modelPaths)))
        models.append(load_model(modelPath))

    # initialize the list of predictions
    print("[INFO] evaluating ensemble...")
    predictions = []

    # loop over the models
    for model in models:
        # use the current model to make predictions on the testing data,
        # then store these predictions in the aggregate predictions list
        predictions.append(model.predict(testX, batch_size=64))

    # average the probabilities across all model predictions, then show a classification report
    predictions = np.average(predictions, axis=0)
    print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=labelNames))

# %%
evaluate_ensemble(models_folder="drive/MyDrive/pyimagesearch/output/25-ensembles/models")
# Out:
# [INFO] loading model 1/5
# [INFO] loading model 2/5
# [INFO] loading model 3/5
# [INFO] loading model 4/5
# [INFO] loading model 5/5
# [INFO] evaluating ensemble...
#               precision    recall  f1-score   support
#
#     airplane       0.85      0.85      0.85      1000
#   automobile       0.90      0.95      0.93      1000
#         bird       0.81      0.70      0.75      1000
#          cat       0.77      0.52      0.62      1000
#         deer       0.76      0.79      0.78      1000
#          dog       0.85      0.64      0.73      1000
#         frog       0.60      0.96      0.74      1000
#        horse       0.88      0.88      0.88      1000
#         ship       0.93      0.90      0.92      1000
#        truck       0.87      0.92      0.89      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.82      0.81      0.81     10000
# weighted avg       0.82      0.81      0.81     10000
